# %% [markdown]
# # Handwritten Equation solver using CNN
# ### **Nitish M. Satheesh**
#
# `Python version 3.9.0`

# %% [markdown]
# ### Imports & stuff

# %%
import json
import os
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input # type: ignore
from tensorflow.keras.models import Model # type: ignore
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D # type: ignore
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.utils import to_categorical # type: ignore
from tqdm import tqdm

# %%
# Path to dataset
BASE_PATH = './aida'

# %% [markdown]
# ### Data Preprocessing
# **Load and Parse JSON Annotations to extract the annotations**

# %%
def load_annotations(batch_num):
    json_path = os.path.join(BASE_PATH, f'batch_{batch_num}', 'JSON', f'kaggle_data_{batch_num}.json')
    with open(json_path, 'r') as file:
        data = json.load(file)
    print(f"  Loaded annotations 'JSON\\kaggle_data_{batch_num}.json'")
    return data

# %% [markdown]
# **Load Images**
#
# Next, load the images from the `background_images` folder.

# %%
def load_images(batch_num):
    image_folder = os.path.join(BASE_PATH, f'batch_{batch_num}', 'background_images')
    images = []
    image_paths = []
    print(f"\n  Loading images from 'batch_{batch_num}\\background_images'", end="\n  ")
    for filename in tqdm(os.listdir(image_folder)):
        img_path = os.path.join(image_folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            images.append(img)
            image_paths.append(img_path)
    print(f"  Loaded {len(image_paths)} images.")
    return images, image_paths

# %% [markdown]
# **Preprocess Images**
#
# Resize and normalize the images to fit the input requirements of MobileNet.

# %%
def preprocess_images(images, target_size=(224, 224)):
    processed_images = []
    print("\n  Preprocessing images", end="\n  ")
    for img in tqdm(images):
        img_resized = cv2.resize(img, target_size)
        img_preprocessed = preprocess_input(img_resized)
        processed_images.append(img_preprocessed)
    print("  Preprocessing images done.")
    return np.array(processed_images)

# %% [markdown]
# ### Data Preparation

# %%
# def prepare_data(batch_nums):
#     all_images = []
#     all_labels = []
#     all_image_paths = []

#     for batch_num in batch_nums:
#         annotations = load_annotations(batch_num)
#         images, image_paths = load_images(batch_num)
        
#         for img, img_path in zip(images, image_paths):
#             img_filename = os.path.basename(img_path)
#             if img_filename in annotations:
#                 all_images.append(img)
#                 all_labels.append(annotations[img_filename]['label'])
#                 all_image_paths.append(img_path)

#     processed_images = preprocess_images(all_images)
#     return processed_images, all_labels, all_image_paths

def prepare_data(batch_nums):
    all_images = []
    all_labels = []
    all_image_paths = []

    for batch_num in batch_nums:
        print(f"\n[~] Processing batch {batch_num}")
        annotations = load_annotations(batch_num)
        images, image_paths = load_images(batch_num)
        
        print(f" [*] Found {len(images)} images and {len(annotations)} annotations")
        
        # Create a dictionary mapping filenames to annotations for faster lookup
        annotation_dict = {item['filename']: item for item in annotations}
        
        # Print first 5 image filenames and first 3 annotation filenames
        print(f"  Sample image filenames: {[os.path.basename(path) for path in image_paths[:3]]}")
        print(f"  Sample annotation filenames: {[item['filename'] for item in annotations[:3]]}")
        
        matched_count = 0
        unmatched_count = 0
        for img, img_path in tqdm(zip(images, image_paths)):
            img_filename = os.path.basename(img_path)
            if img_filename in annotation_dict:
                latex = annotation_dict[img_filename].get('latex')
                if latex:  # Check if latex is not None or empty string
                    all_images.append(img)
                    all_labels.append(latex)
                    all_image_paths.append(img_path)
                    matched_count += 1
                else:
                    unmatched_count += 1
                    print(f"[!] Image {img_filename} found in annotations but has no latex")
            else:
                unmatched_count += 1
                if unmatched_count <= 5:  # Print only first 5 unmatched files to avoid cluttering the output
                    print(f"[!] Image {img_filename} not found in annotations")
        
        print(f"  Matched {matched_count} images with annotations")
        print(f"  Unmatched {unmatched_count} images")

    print(f"[*] Total processed images: {len(all_images)}")
    print(f"[*] Total labels: {len(all_labels)}")
    print(f"[*] Sample labels: {all_labels[:5]}")  # Print first 5 labels for inspection

    if not all_labels:
        raise ValueError("[!] No valid labels found in the dataset")

    processed_images = preprocess_images(all_images)
    return processed_images, all_labels, all_image_paths

# %%
# FIXME: Change range to (1, 11). Using only batch 1 for now
BATCH_NUMS = range(1, 2)

# Prepare data
X, y, image_paths = prepare_data(BATCH_NUMS)

print()
print(f"[INFO] Shape of X: {X.shape}")
print(f"[INFO] Length of y: {len(y)}")

# Get unique labels and create a label-to-index mapping
unique_labels = list(set(y))
print(f"[INFO] Number of unique labels: {len(unique_labels)}")
print(f"[INFO] Sample unique labels: {unique_labels[:5]}")  # Print first 5 unique labels

label_to_index = {label: index for index, label in enumerate(unique_labels)}

# Convert string labels to indices
y_indices = [label_to_index[label] for label in y]

print(f"[INFO] Sample y_indices: {y_indices[:5]}")  # Print first 5 indices

# Convert to one-hot encoding
num_classes = len(unique_labels)
y_one_hot = to_categorical(y_indices, num_classes=num_classes)
# Out:
# [---] Processing batch 1
#  [*] Loaded annotations 'JSON\kaggle_data_1.json'
#  [---] Loading images from 'batch_1\background_images'
# 100%|██████████| 10000/10000 [01:36<00:00, 103.52it/s]
#  [*] Loaded 10000 images.
#  [*] Found 10000 images and 10000 annotations
#  [*] Sample image filenames: ['00063690-954d-42e7-86eb-434d9416ead3.jpg', '00095b3c-cd87-4326-addc-9225a6042407.jpg', '000f3f60-c994-4df4-81ca-0c10e3feb67c.jpg']
#  [*] Sample annotation filenames: ['bd85ee85-2549-4539-9cd9-122d0ea3dca2.jpg', 'e97b0b1f-08bf-4c2b-86cb-f264af2160df.jpg', '3c72e1a1-c1de-4d67-a0ad-9f7afb6cee01.jpg']
# 10000it [00:00, 90183.41it/s]
#   [>] Matched 10000 images with annotations
#   [>] Unmatched 0 images
# [*] Total processed images: 10000
# [*] Total labels: 10000
# [*] Sample labels: ['\\lim_{v\\to3}\\frac{\\frac{d}{dv}\\left(e^{v}+-2\\sin{v}-9\\right)}{\\frac{d}{dv}\\left(v^{1}+1v^{9}+98v^{4}\\right)}', '\\lim_{c\\to\\frac{\\pi}{3}}\\frac{\\cos^{9}{c}+\\tan^{3}{c}}{3}', '\\lim_{a\\to\\infty}\\frac{9}{a^{-2}}\\left(\\frac{9}{a}+-9\\sin{\\frac{5}{a}}\\right)', '\\lim_{\\theta\\to\\pi/3}\\frac{9\\cos^{8}{\\theta}+8\\cos^{4}{\\theta}}{9}', '\\ln{w}=\\lim_{v\\to2^{+}}v\\left|\\ln{v}\\right|']
# [---] Preprocessing images
# 100%|██████████| 10000/10000 [02:01<00:00, 81.97it/s]
# [*] Preprocessing images done.
# [INFO] Shape of X: (10000, 224, 224, 3)
# [INFO] Length of y: 10000
# [INFO] Number of unique labels: 9997
# [INFO] Sample unique labels: ['\\lim_{t\\to7^{+}}\\frac{\\frac{d}{dt}\\left(0+-\\cos^{4}{t}\\right)}{\\frac{d}{dt}\\left(\\sin{t}+t\\cos^{6}{t}\\right)}', '\\lim_{a\\to3^{+}}\\frac{2}{a^{4}+-7a}', '\\lim_{s\\to8}\\frac{\\left(s-5\\right)\\left(s-4\\right)}{s-8}', '\\lim_{\\theta\\to0}\\frac{2}{\\pi^{9}\\left(\\sin^{8}{\\left(\\pi\\theta\\right)}+9\\tan^{2}{\\left(\\pi\\theta\\right)}\\right)}', '\\lim_{x\\to\\pi/6^{-}}5/5\\cos^{5}{x}\\left(2x+\\left(-5\\pi\\right)^{9}\\right)']
# [INFO] Sample y_indices: [6651, 1569, 8530, 2843, 5141]

# %% [markdown]
# ### Training MobileNet model
#
#
# **Methods for defining, compiling and training the model**

# %%
def create_model(num_classes):
    base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

def train_model(model, X_train, y_train, epochs=10, batch_size=32):
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2)

# %% [markdown]
# **Implementation**

# %%
# Create and train the model
model = create_model(num_classes)
train_model(model, X, y_one_hot)

# Save the model
model.save('models/aida_mobilenet_model.keras')

# Save the label mapping
with open('label_mapping.json', 'w') as f:
    json.dump(label_to_index, f)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 502s 2s/step - accuracy: 0.0000e+00 - loss: 9.3044 - val_accuracy: 0.0000e+00 - val_loss: 9.2343
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.0306 - loss: 8.7639 - val_accuracy: 0.0000e+00 - val_loss: 10.5616
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.4056 - loss: 4.5297 - val_accuracy: 0.0000e+00 - val_loss: 13.4030
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.9510 - loss: 0.6906 - val_accuracy: 0.0000e+00 - val_loss: 15.1821
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 476s 2s/step - accuracy: 0.9999 - loss: 0.0549 - val_accuracy: 0.0000e+00 - val_loss: 15.0671
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.0000e+00 - val_loss: 15.2432
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 513s 2s/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.0000e+00 - val_loss: 15.3444
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 553s 2s/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.0000e+00 - val_loss: 15.5274
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 576s 2s/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.0000e+00 - val_loss: 15.6447
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.0000e+00 - val_loss: 15.7185
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Evaluation

# %%
# FIXME: Change range to load the test data
BATCH_NUMS = range(2, 3)

# Prepare data
X_eval, y_eval, image_paths = prepare_data(BATCH_NUMS)

print()
print(f"[INFO] Shape of X: {X_eval.shape}")
print(f"[INFO] Length of y: {len(y_eval)}")

# Get unique labels and create a label-to-index mapping
unique_labels = list(set(y_eval))
print(f"[INFO] Number of unique labels: {len(unique_labels)}")
print(f"[INFO] Sample unique labels: {unique_labels[:5]}")  # Print first 5 unique labels

label_to_index = {label: index for index, label in enumerate(unique_labels)}

# Convert string labels to indices
y_eval_indices = [label_to_index[label] for label in y_eval]

print(f"[INFO] Sample y_indices: {y_eval_indices[:5]}")  # Print first 5 indices

# Convert to one-hot encoding
num_classes = len(unique_labels)
y_eval_one_hot = to_categorical(y_eval_indices, num_classes=num_classes)
# Out:
# [---] Processing batch 2
#  [*] Loaded annotations 'JSON\kaggle_data_2.json'
#  [---] Loading images from 'batch_2\background_images'
# 100%|██████████| 10000/10000 [02:31<00:00, 65.98it/s]
#  [*] Loaded 10000 images.
#  [*] Found 10000 images and 10000 annotations
#  [*] Sample image filenames: ['00110449-640f-4e28-a238-f05e36278690.jpg', '001b0b6b-42c1-4516-86e6-367c4de17d6e.jpg', '002588d9-5f86-4b33-9038-4422e57a1c2a.jpg']
#  [*] Sample annotation filenames: ['9f6d0918-cc25-4796-b01d-fbd71baf5fdf.jpg', '20cb4215-8c1b-4a7a-bbe9-c71f6fe73fa5.jpg', '51df991b-6a4e-444d-a460-874c68ece435.jpg']
# 10000it [00:00, 12078.37it/s]
#   [>] Matched 10000 images with annotations
#   [>] Unmatched 0 images
# [*] Total processed images: 10000
# [*] Total labels: 10000
# [*] Sample labels: ['\\lim_{c\\to1^{+}}c^{\\sin{c}}', '\\lim_{t\\to\\infty}\\frac{\\log_{43}{t}}{\\log_{48}{8}}\\frac{\\log_{10}{7}}{\\log_{84}{t}}', '\\lim_{b\\to5^{-}}\\frac{b\\left(b-5\\right)}{\\left|b\\right|}', 'u\\lim_{h\\to1}\\frac{h^{1}+-5h}{h^{2}+-h+9}', '\\lim_{w\\to\\pi/2^{-}}\\frac{\\sin^{8}{w}\\left(2w+\\left(-7\\pi\\right)^{6}\\right)}{-2}']
# [---] Preprocessing images
# 100%|██████████| 10000/10000 [02:32<00:00, 65.56it/s]
# [*] Preprocessing images done.
# [INFO] Shape of X: (10000, 224, 224, 3)
# [INFO] Length of y: 10000
# [INFO] Number of unique labels: 9998
# [INFO] Sample unique labels: ['\\lim_{x\\to\\infty}\\frac{8}{e^{x}}', '\\lim_{v\\to\\infty}\\frac{\\log_{72}{v}}{\\log_{13}{6}}\\frac{\\log_{79}{2}}{\\log_{21}{v}}', '\\lim_{z\\to\\frac{\\pi}{3}^{-}}\\frac{\\sin^{2}{z}\\left(9z+\\left(-4\\pi\\right)^{3}\\right)}{-2}', '\\lim_{w\\to5^{+}}\\frac{\\frac{9}{w}}{-8\\cot{w}\\sin{w}}', '\\lim_{p\\to3}\\frac{e^{p}+-5\\sin{p}-2}{p^{3}+7p^{9}+11p^{6}}']
# [INFO] Sample y_indices: [2612, 5852, 3077, 4481, 5768]

# %%
from sklearn.metrics import classification_report, accuracy_score

# Evaluate on the evaluation set
def evaluate_model(model, X_test, y_test, label_to_index):
    predictions = model.predict(X_test)
    predicted_indices = np.argmax(predictions, axis=1)
    true_indices = np.argmax(y_test, axis=1)
    
    # Convert indices back to labels
    index_to_label = {index: label for label, index in label_to_index.items()}
    predicted_labels = [index_to_label[idx] for idx in predicted_indices]
    true_labels = [index_to_label[idx] for idx in true_indices]
    
    # Accuracy
    accuracy = accuracy_score(true_labels, predicted_labels)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    
    # Classification report
    print(classification_report(true_labels, predicted_labels))

# %%
from sklearn.model_selection import train_test_split

# Split the data (e.g., 80% for training, 20% for evaluation)
# _, X_eval, _, y_eval = train_test_split(X, y_one_hot, test_size=0.05, random_state=0)

# Evaluate the model
evaluate_model(model, X_eval, y_eval_one_hot, label_to_index)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 123s 385ms/step
# Accuracy: 0.02%
# c:\Users\Nitish\Desktop\Minor prj\heqn\.env39\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Nitish\Desktop\Minor prj\heqn\.env39\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                                                                                                                                                                             precision    recall  f1-score   support
#
#                                                                                                                                                              -2\lim_{c\to-\infty}\ln{\left|c^{9}+6\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -2\lim_{t\to-\infty}\ln{\left|t^{2}+0\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -2\lim_{w\to-\infty}\ln{\left|w^{0}+0\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                  -2\lim_{w\to-\infty}w^{5}       0.00      0.00      0.00         1
#                                                                                                                                                              -2\lim_{y\to-\infty}\ln{\left|y^{3}+6\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -2\lim_{y\to-\infty}\ln{\left|y^{9}+9\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                        -3\lim_{\theta\to-\infty}\theta^{5}       0.00      0.00      0.00         1
#                                                                                                                                                              -3\lim_{b\to-\infty}\ln{\left|b^{6}+4\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -3\lim_{c\to-\infty}\ln{\left|c^{2}+1\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -3\lim_{c\to-\infty}\ln{\left|c^{4}+2\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -3\lim_{v\to-\infty}\ln{\left|v^{1}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                  -3\lim_{v\to-\infty}v^{1}       0.00      0.00      0.00         1
#                                                                                                                                                              -3\lim_{w\to-\infty}\ln{\left|w^{1}+2\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -4\lim_{c\to-\infty}\ln{\left|c^{3}+8\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -4\lim_{g\to-\infty}\ln{\left|g^{8}+8\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                  -4\lim_{n\to-\infty}n^{6}       0.00      0.00      0.00         1
#                                                                                                                                                              -4\lim_{x\to-\infty}\ln{\left|x^{4}+4\right|}       0.00      0.00      0.00         1
#                                                                                                                                                    -5\lim_{\theta\to-\infty}\ln{\left|\theta^{8}+2\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -5\lim_{p\to-\infty}\ln{\left|p^{8}+7\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -5\lim_{v\to-\infty}\ln{\left|v^{9}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -5\lim_{x\to-\infty}\ln{\left|x^{2}+9\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                  -5\lim_{x\to-\infty}x^{5}       0.00      0.00      0.00         1
#                                                                                                                                                              -5\lim_{y\to-\infty}\ln{\left|y^{8}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -6\lim_{c\to-\infty}\ln{\left|c^{9}+7\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -6\lim_{h\to-\infty}\ln{\left|h^{7}+2\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                  -6\lim_{n\to-\infty}n^{8}       0.00      0.00      0.00         1
#                                                                                                                                                    -7\lim_{\theta\to-\infty}\ln{\left|\theta^{2}+4\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -7\lim_{h\to-\infty}\ln{\left|h^{2}+8\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -7\lim_{k\to-\infty}\ln{\left|k^{2}+1\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -7\lim_{u\to-\infty}\ln{\left|u^{1}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -8\lim_{k\to-\infty}\ln{\left|k^{3}+4\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -8\lim_{s\to-\infty}\ln{\left|s^{2}+5\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -8\lim_{u\to-\infty}\ln{\left|u^{5}+9\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -8\lim_{x\to-\infty}\ln{\left|x^{7}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              -9\lim_{x\to-\infty}\ln{\left|x^{5}+0\right|}       0.00      0.00      0.00         1
#                                                                                                                                                               -\lim_{a\to-\infty}\ln{\left|a^{0}+1\right|}       0.00      0.00      0.00         1
#                                                                                                                                                               -\lim_{t\to-\infty}\ln{\left|t^{1}+1\right|}       0.00      0.00      0.00         1
#                                                                                                                                                               0\lim_{w\to-\infty}\ln{\left|w^{6}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              1\lim_{n\to2}\frac{\sin{\left(9n\right)}}{2n}       0.00      0.00      0.00         1
#                                                                                                                                                               1\lim_{v\to2}\frac{\cos{\left(2v\right)}}{v}       0.00      0.00      0.00         1
#                                                                                                                                                              1\lim_{w\to2}\frac{\sin{\left(8w\right)}}{7w}       0.00      0.00      0.00         1
#                                                                                                                                                 2/2\lim_{b\to\pi/8^{-}}\frac{2}{\tan^{7}{b}+-2\tan^{4}{b}}       0.00      0.00      0.00         1
#                                                                                                                                                            2/2\lim_{r\to2}\frac{\tan{\left(9r\right)}}{4r}       0.00      0.00      0.00         1
#                                                                                                                                     2/2\lim_{z\to\pi/5^{-}}\frac{2\left(5z+-7\pi\right)}{-8\tan{z}\cos{z}}       0.00      0.00      0.00         1
#                                                                                                                                      2/3\lim_{w\to\infty}\frac{\frac{-7\sin{8/w}}{w^{8}}}{\frac{5}{w^{6}}}       0.00      0.00      0.00         1
#                                                                                                                                      2/3\lim_{x\to\infty}\frac{\frac{-5\tan{2/x}}{x^{6}}}{\frac{3}{x^{2}}}       0.00      0.00      0.00         1
#                                                                                                                                                               2/3\lim_{y\to\infty}\frac{\tan{3/y}}{y^{-3}}       0.00      0.00      0.00         1
#                                                                                                                                                  2/4\lim_{c\to\pi/7^{-}}\frac{3}{\tan^{5}{c}+6\cot^{2}{c}}       0.00      0.00      0.00         1
#                                                                                                                                                            2/4\lim_{s\to3}\frac{\cos{\left(5s\right)}}{2s}       0.00      0.00      0.00         1
#                                                                                                                                                          2/4\lim_{x\to4}\frac{\sin{\left(2x\right)}}{x}2/8       0.00      0.00      0.00         1
#                                                                                              2/4\lim_{y\to3}\frac{\frac{\sin{\left(7y\right)}}{4y}\cos{\left(3y\right)}}{\frac{\sin{\left(5y\right)}}{9y}}       0.00      0.00      0.00         1
#                                                                                                                                            2/5\lim_{\theta\to8}\frac{6\tan{\left(3\theta\right)}}{3\theta}       0.00      0.00      0.00         1
#                                                                                                                                                  2/6\lim_{c\to\pi/4^{-}}\frac{2}{\cos^{4}{c}+2\tan^{2}{c}}       0.00      0.00      0.00         1
#                                                                                              2/6\lim_{u\to5}\frac{\frac{\tan{\left(6u\right)}}{7u}\sin{\left(3u\right)}}{\frac{\sec{\left(9u\right)}}{8u}}       0.00      0.00      0.00         1
#                                                                                                           2/6\lim_{x\to\infty}\frac{\frac{d}{dx}\left(\sin{2/x}+-56/x\cot{2/x}\right)}{\frac{d}{dx}x^{-5}}       0.00      0.00      0.00         1
#                                                                                                                                                            2/7\lim_{z\to3}\frac{\sec{\left(2z\right)}}{4z}       0.00      0.00      0.00         1
#                                                                                                                                                               2/8\lim_{c\to\infty}\frac{\tan{2/c}}{c^{-4}}       0.00      0.00      0.00         1
#                                                                                                                                                     2/8\lim_{h\to\pi/8^{-}}\frac{2h+-8\pi}{\tan{h}\cos{h}}       0.00      0.00      0.00         1
#                                                                                              2/8\lim_{p\to3}\frac{\frac{\sin{\left(5p\right)}}{7p}\cos{\left(2p\right)}}{\frac{\sin{\left(5p\right)}}{9p}}       0.00      0.00      0.00         1
#                                                                                                           2/9\lim_{h\to\infty}\frac{\frac{d}{dh}\left(\cos{2/h}+-22/h\cos{5/h}\right)}{\frac{d}{dh}h^{-4}}       0.00      0.00      0.00         1
#                                                                                                                                                                                       2\lim_{c\to-\infty}c       0.00      0.00      0.00         1
#                                                                                                                                                                                       2\lim_{g\to-\infty}g       0.00      0.00      0.00         1
#                                                                                                                                                                                       2\lim_{u\to-\infty}u       0.00      0.00      0.00         1
#                                                                                              3/2\lim_{h\to4}\frac{\frac{\sin{\left(7h\right)}}{4h}\cos{\left(9h\right)}}{\frac{\tan{\left(4h\right)}}{8h}}       0.00      0.00      0.00         1
#                                                                                                                                                          3/2\lim_{t\to7}\frac{\sin{\left(3t\right)}}{t}8/2       0.00      0.00      0.00         1
#                                                                                                                                                            3/2\lim_{v\to6}\frac{\tan{\left(2v\right)}}{9v}       0.00      0.00      0.00         1
#                                                                                                                                                     3/2\lim_{w\to\pi/9^{-}}\frac{5w+-6\pi}{\sin{w}\sec{w}}       0.00      0.00      0.00         1
#                                                                                                                                                  3/3\lim_{u\to\pi/5^{-}}\frac{3}{\tan^{8}{u}+4\sin^{2}{u}}       0.00      0.00      0.00         1
#                                                                                                                                               3/3\lim_{v\to\infty}\frac{-2\cos{2/v}}{v^{7}}\frac{v^{4}}{9}       0.00      0.00      0.00         1
#                                                                                                  3/4\lim_{k\to\pi/4^{-}}\frac{\frac{d}{dk}\left(9k+\left(-6\pi\right)^{3}\right)}{\frac{d}{dk}\tan^{3}{k}}       0.00      0.00      0.00         1
#                                                                                                                                                  3/4\lim_{r\to\pi/2^{-}}\frac{3}{\tan^{5}{r}+7\tan^{9}{r}}       0.00      0.00      0.00         1
#                                                                                                                                                     3/4\lim_{x\to\pi/3^{-}}\frac{2x+-2\pi}{\cos{x}\tan{x}}       0.00      0.00      0.00         1
#                                                                                                           3/5\lim_{h\to\infty}\frac{\frac{d}{dh}\left(\tan{2/h}+-59/h\cos{7/h}\right)}{\frac{d}{dh}h^{-3}}       0.00      0.00      0.00         1
#                                                                                                                                                               3/5\lim_{p\to\infty}\frac{\cos{3/p}}{p^{-8}}       0.00      0.00      0.00         1
#                                                                                              3/5\lim_{t\to2}\frac{\frac{\cos{\left(6t\right)}}{7t}\cos{\left(2t\right)}}{\frac{\csc{\left(9t\right)}}{3t}}       0.00      0.00      0.00         1
#                                                                                                                                                               3/5\lim_{v\to\infty}\frac{\tan{7/v}}{v^{-4}}       0.00      0.00      0.00         1
#                                                                                              3/6\lim_{n\to2}\frac{\frac{\sec{\left(9n\right)}}{7n}\sin{\left(7n\right)}}{\frac{\sin{\left(9n\right)}}{4n}}       0.00      0.00      0.00         1
#                                                                                                                                                           3/6\lim_{s\to6}\frac{2\cos{\left(4s\right)}}{3s}       0.00      0.00      0.00         1
#                                                                                                           3/6\lim_{s\to\infty}\frac{\frac{d}{ds}\left(\cos{8/s}+-62/s\sin{2/s}\right)}{\frac{d}{ds}s^{-7}}       0.00      0.00      0.00         1
#                                                                                                                                                          3/6\lim_{z\to6}\frac{\sin{\left(4z\right)}}{z}2/5       0.00      0.00      0.00         1
#                                                                                                                                                           3/7\lim_{x\to7}\frac{5\tan{\left(5x\right)}}{7x}       0.00      0.00      0.00         1
#                                                                        3/8\lim_{\theta\to\infty}\frac{\frac{d}{d\theta}\left(\tan{9/\theta}+-32/\theta\tan{2/\theta}\right)}{\frac{d}{d\theta}\theta^{-2}}       0.00      0.00      0.00         1
#                                                                                                                                               3/9\lim_{s\to\infty}\frac{3\cot{2/s}}{s^{5}}\frac{s^{8}}{-2}       0.00      0.00      0.00         1
#                                                                                                                                               3\lim_{\theta\to1}\frac{\sin{\left(5\theta\right)}}{3\theta}       0.00      0.00      0.00         1
#                                                                                                                                                              3\lim_{p\to4}\frac{\sin{\left(5p\right)}}{2p}       0.00      0.00      0.00         1
#                                                                                                                                                                                       3\lim_{y\to-\infty}y       0.00      0.00      0.00         1
#                                                                                                                                                  4/2\lim_{s\to\pi/2^{-}}\frac{2}{\sin^{6}{s}+5\tan^{8}{s}}       0.00      0.00      0.00         1
#                                                                                                                   4/2\lim_{u\to2}\frac{\frac{\sin{\left(7u\right)}}{5u}}{\frac{\sin{\left(2u\right)}}{3u}}       0.00      0.00      0.00         1
#                                                                                                                                               4/2\lim_{v\to\infty}\frac{2\cos{3/v}}{v^{2}}\frac{v^{9}}{-3}       0.00      0.00      0.00         1
#                                                                                                                                                     4/2\lim_{y\to\pi/3^{-}}\frac{2y+-7\pi}{\sec{y}\cos{y}}       0.00      0.00      0.00         1
#                                                                                                                                     4/3\lim_{c\to\pi/3^{-}}\frac{9\left(3c+-2\pi\right)}{-4\sin{c}\sin{c}}       0.00      0.00      0.00         1
#                                                                                                                                      4/4\lim_{w\to\infty}\frac{\frac{-2\cos{5/w}}{w^{2}}}{\frac{2}{w^{5}}}       0.00      0.00      0.00         1
#                                                                                              4/4\lim_{x\to2}\frac{\frac{\sin{\left(2x\right)}}{4x}\cos{\left(2x\right)}}{\frac{\tan{\left(5x\right)}}{6x}}       0.00      0.00      0.00         1
#                                                                                                                                                  4/4\lim_{x\to\pi/3^{-}}\frac{2}{\tan^{5}{x}+6\sin^{4}{x}}       0.00      0.00      0.00         1
#                                                                                                                                                            4/5\lim_{u\to4}\frac{\sin{\left(4u\right)}}{5u}       0.00      0.00      0.00         1
#                                                                                                                                                     4/7\lim_{t\to\pi/3^{-}}\frac{2t+-3\pi}{\sin{t}\sin{t}}       0.00      0.00      0.00         1
#                                                                                                                                                          4/7\lim_{y\to2}\frac{\cos{\left(2y\right)}}{y}4/3       0.00      0.00      0.00         1
#                                                                                              4/7\lim_{z\to4}\frac{\frac{\sin{\left(7z\right)}}{3z}\cos{\left(8z\right)}}{\frac{\sin{\left(5z\right)}}{7z}}       0.00      0.00      0.00         1
#                                                                                              4/9\lim_{p\to6}\frac{\frac{\sin{\left(6p\right)}}{3p}\sin{\left(9p\right)}}{\frac{\sin{\left(3p\right)}}{6p}}       0.00      0.00      0.00         1
#                                                                                                                                                                                       4\lim_{t\to-\infty}t       0.00      0.00      0.00         1
#                                                                                                                                                     5/2\lim_{g\to\pi/7^{-}}\frac{7g+-9\pi}{\sin{g}\sin{g}}       0.00      0.00      0.00         1
#                                                                                                                                     5/2\lim_{k\to\pi/7^{-}}\frac{2\left(4k+-6\pi\right)}{-6\tan{k}\sin{k}}       0.00      0.00      0.00         1
#                                                                                                                                                            5/2\lim_{u\to6}\frac{\tan{\left(3u\right)}}{3u}       0.00      0.00      0.00         1
#                                                                                                                                                     5/4\lim_{a\to\pi/3^{-}}\frac{8a+-7\pi}{\cot{a}\tan{a}}       0.00      0.00      0.00         1
#                                                                                                                                                           5/5\lim_{a\to4}\frac{2\sin{\left(5a\right)}}{2a}       0.00      0.00      0.00         1
#                                                                                                                                                          5/5\lim_{n\to5}\frac{\sin{\left(3n\right)}}{n}7/7       0.00      0.00      0.00         1
#                                                                                                           5/5\lim_{u\to\infty}\frac{\frac{d}{du}\left(\sec{6/u}+-26/u\cos{2/u}\right)}{\frac{d}{du}u^{-8}}       0.00      0.00      0.00         1
#                                                                                                                                                               5/6\lim_{c\to\infty}\frac{\cos{4/c}}{c^{-3}}       0.00      0.00      0.00         1
#                                                                                                                                                 5/6\lim_{k\to\pi/4^{-}}\frac{5}{\sin^{7}{k}+-6\sin^{5}{k}}       0.00      0.00      0.00         1
#                                                                                                                                                     5/6\lim_{t\to\pi/3^{-}}\frac{2t+-4\pi}{\sin{t}\csc{t}}       0.00      0.00      0.00         1
#                                                                                                                                               5/7\lim_{v\to\infty}\frac{-7\cos{9/v}}{v^{2}}\frac{v^{8}}{8}       0.00      0.00      0.00         1
#                                                                                                           5/8\lim_{h\to\infty}\frac{\frac{d}{dh}\left(\cos{8/h}+-62/h\sin{4/h}\right)}{\frac{d}{dh}h^{-7}}       0.00      0.00      0.00         1
#                                                                                                                                                 5/8\lim_{h\to\pi/6^{-}}\frac{9}{\cos^{3}{h}+-4\csc^{4}{h}}       0.00      0.00      0.00         1
#                                                                                                                                                 5/8\lim_{x\to\pi/4^{-}}\frac{7}{\sin^{6}{x}+-3\sin^{8}{x}}       0.00      0.00      0.00         1
#                                                                                                                   6/2\lim_{h\to3}\frac{\frac{\sin{\left(3h\right)}}{3h}}{\frac{\sin{\left(4h\right)}}{6h}}       0.00      0.00      0.00         1
#                                                                                              6/2\lim_{r\to7}\frac{\frac{\tan{\left(5r\right)}}{6r}\sin{\left(9r\right)}}{\frac{\sin{\left(2r\right)}}{9r}}       0.00      0.00      0.00         1
#                                                                                                  6/3\lim_{a\to\pi/3^{-}}\frac{\frac{d}{da}\left(9a+\left(-5\pi\right)^{3}\right)}{\frac{d}{da}\sin^{4}{a}}       0.00      0.00      0.00         1
#                                                                                                                                                  6/3\lim_{c\to\pi/5^{-}}\frac{4}{\csc^{2}{c}+9\csc^{7}{c}}       0.00      0.00      0.00         1
#                                                                                                                                                 6/3\lim_{h\to\pi/3^{-}}\frac{5}{\tan^{3}{h}+-3\cos^{3}{h}}       0.00      0.00      0.00         1
#                                                                                                                                     6/3\lim_{p\to\pi/4^{-}}\frac{8\left(3p+-2\pi\right)}{-2\tan{p}\sin{p}}       0.00      0.00      0.00         1
#                                                                                                                                                  6/4\lim_{b\to\pi/2^{-}}\frac{4}{\sin^{2}{b}+7\sin^{6}{b}}       0.00      0.00      0.00         1
#                                                                                                                                                            6/4\lim_{y\to3}\frac{\sin{\left(4y\right)}}{2y}       0.00      0.00      0.00         1
#                                                                                                                                     6/5\lim_{g\to\pi/3^{-}}\frac{9\left(3g+-8\pi\right)}{-4\sin{g}\tan{g}}       0.00      0.00      0.00         1
#                                                                                                           6/6\lim_{t\to\infty}\frac{\frac{d}{dt}\left(\tan{2/t}+-27/t\sin{6/t}\right)}{\frac{d}{dt}t^{-8}}       0.00      0.00      0.00         1
#                                                                                                                   6/7\lim_{u\to5}\frac{\frac{\tan{\left(3u\right)}}{4u}}{\frac{\cot{\left(7u\right)}}{8u}}       0.00      0.00      0.00         1
#                                                                                                                                                              6\lim_{x\to3}\frac{\tan{\left(2x\right)}}{2x}       0.00      0.00      0.00         1
#                                                                                                                                                  7/2\lim_{n\to\pi/8^{-}}\frac{4}{\sin^{8}{n}+7\tan^{6}{n}}       0.00      0.00      0.00         1
#                                                                                                                                                  7/2\lim_{w\to\pi/2^{-}}\frac{5}{\tan^{5}{w}+2\sin^{3}{w}}       0.00      0.00      0.00         1
#                                                                                                                                     7/3\lim_{g\to\pi/7^{-}}\frac{2\left(5g+-7\pi\right)}{-4\sin{g}\cos{g}}       0.00      0.00      0.00         1
#                                                                                                                                                  7/3\lim_{n\to\pi/3^{-}}\frac{4}{\tan^{2}{n}+4\sin^{8}{n}}       0.00      0.00      0.00         1
#                                                                                              7/3\lim_{t\to5}\frac{\frac{\tan{\left(4t\right)}}{5t}\tan{\left(3t\right)}}{\frac{\sin{\left(9t\right)}}{6t}}       0.00      0.00      0.00         1
#                                                                                                                                   7/4\lim_{\theta\to\pi/4^{-}}\frac{3}{\sin^{3}{\theta}+6\sin^{2}{\theta}}       0.00      0.00      0.00         1
#                                                                                                                                                           7/4\lim_{p\to2}\frac{9\sin{\left(5p\right)}}{6p}       0.00      0.00      0.00         1
#                                                                                                  7/4\lim_{x\to\pi/4^{-}}\frac{\frac{d}{dx}\left(4x+\left(-2\pi\right)^{7}\right)}{\frac{d}{dx}\tan^{2}{x}}       0.00      0.00      0.00         1
#                                                                                                                                                  7/5\lim_{k\to\pi/9^{-}}\frac{3}{\tan^{9}{k}+8\tan^{5}{k}}       0.00      0.00      0.00         1
#                                                                                                                                                  7/6\lim_{y\to\pi/4^{-}}\frac{2}{\cos^{3}{y}+5\tan^{3}{y}}       0.00      0.00      0.00         1
#                                                                                                                                                     7/7\lim_{w\to\pi/2^{-}}\frac{9w+-3\pi}{\sin{w}\tan{w}}       0.00      0.00      0.00         1
#                                                                                                                                                  7/8\lim_{b\to\pi/4^{-}}\frac{7}{\sin^{5}{b}+9\sin^{5}{b}}       0.00      0.00      0.00         1
#                                                                                                                                                            7/9\lim_{x\to8}\frac{\tan{\left(7x\right)}}{3x}       0.00      0.00      0.00         1
#                                                                                                                                                               7\lim_{w\to8}\frac{\cos{\left(w\right)}}{5w}       0.00      0.00      0.00         1
#                                                                                                                                                              7\lim_{z\to9}\frac{\sec{\left(8z\right)}}{9z}       0.00      0.00      0.00         1
#                                                                                                                                                               8/2\lim_{c\to\infty}\frac{\sec{3/c}}{c^{-6}}       0.00      0.00      0.00         1
#                                                                                                                  8/3\lim_{\theta\to\infty}\frac{\frac{8\tan{3/\theta}}{\theta^{4}}}{\frac{-5}{\theta^{3}}}       0.00      0.00      0.00         1
#                                                                                                                                 8/3\lim_{\theta\to\pi/8^{-}}\frac{2\theta+-3\pi}{\cos{\theta}\tan{\theta}}       0.00      0.00      0.00         1
#                                                                                                                                                               8/3\lim_{u\to\infty}\frac{\tan{9/u}}{u^{-2}}       0.00      0.00      0.00         1
#                                                                                                                                                           8/4\lim_{p\to3}\frac{9\sin{\left(6p\right)}}{4p}       0.00      0.00      0.00         1
#                                                                                                           8/4\lim_{y\to\infty}\frac{\frac{d}{dy}\left(\cos{6/y}+-58/y\cos{6/y}\right)}{\frac{d}{dy}y^{-2}}       0.00      0.00      0.00         1
#                                                                                                                                                           8/5\lim_{g\to3}\frac{7\sec{\left(8g\right)}}{2g}       0.00      0.00      0.00         1
#                                                                                              8/6\lim_{x\to9}\frac{\frac{\tan{\left(9x\right)}}{9x}\cos{\left(3x\right)}}{\frac{\cos{\left(6x\right)}}{3x}}       0.00      0.00      0.00         1
#                                                                                                                                                  8/7\lim_{x\to\pi/9^{-}}\frac{2}{\tan^{2}{x}+2\sec^{5}{x}}       0.00      0.00      0.00         1
#                                                                                                           8/8\lim_{b\to\infty}\frac{\frac{d}{db}\left(\sin{2/b}+-47/b\tan{3/b}\right)}{\frac{d}{db}b^{-5}}       0.00      0.00      0.00         1
#                                                                                                                                                          8/8\lim_{v\to2}\frac{\sin{\left(2v\right)}}{v}4/2       0.00      0.00      0.00         1
#                                                                                              8/9\lim_{u\to2}\frac{\frac{\sin{\left(9u\right)}}{8u}\sin{\left(4u\right)}}{\frac{\cos{\left(4u\right)}}{2u}}       0.00      0.00      0.00         1
#                                                                                                                                                     8/9\lim_{y\to\pi/3^{-}}\frac{3y+-2\pi}{\tan{y}\tan{y}}       0.00      0.00      0.00         1
#                                                                                                                                                               8\lim_{g\to5}\frac{\cos{\left(3g\right)}}{g}       0.00      0.00      0.00         1
#                                                                                                                                                          9/2\lim_{h\to8}\frac{\sin{\left(8h\right)}}{h}5/6       0.00      0.00      0.00         1
#                                                                                                                                                 9/2\lim_{k\to\pi/8^{-}}\frac{2}{\tan^{2}{k}+-8\tan^{5}{k}}       0.00      0.00      0.00         1
#                                                                                                                                                     9/2\lim_{u\to\pi/4^{-}}\frac{2u+-3\pi}{\tan{u}\cos{u}}       0.00      0.00      0.00         1
#                                                                                                                                     9/2\lim_{y\to\pi/6^{-}}\frac{4\left(7y+-8\pi\right)}{-3\sin{y}\tan{y}}       0.00      0.00      0.00         1
#                                                                                                                                   9/3\lim_{\theta\to\pi/7^{-}}\frac{2}{\sin^{8}{\theta}+7\sec^{3}{\theta}}       0.00      0.00      0.00         1
#                                                                                                                                                     9/3\lim_{h\to\pi/2^{-}}\frac{4h+-8\pi}{\sin{h}\sin{h}}       0.00      0.00      0.00         1
#                                                                                                           9/3\lim_{w\to\infty}\frac{\frac{d}{dw}\left(\sin{4/w}+-42/w\cos{8/w}\right)}{\frac{d}{dw}w^{-5}}       0.00      0.00      0.00         1
#                                                                                                                                     9/3\lim_{y\to\pi/2^{-}}\frac{8\left(4y+-5\pi\right)}{-9\sin{y}\cos{y}}       0.00      0.00      0.00         1
#                                                                                              9/4\lim_{k\to6}\frac{\frac{\sin{\left(7k\right)}}{3k}\cos{\left(2k\right)}}{\frac{\sin{\left(5k\right)}}{7k}}       0.00      0.00      0.00         1
#                                                                                              9/4\lim_{r\to4}\frac{\frac{\sin{\left(3r\right)}}{3r}\cot{\left(5r\right)}}{\frac{\sin{\left(7r\right)}}{6r}}       0.00      0.00      0.00         1
#                                                                                                                                                     9/5\lim_{t\to\pi/4^{-}}\frac{5t+-5\pi}{\sin{t}\tan{t}}       0.00      0.00      0.00         1
#                                                                                                                                                 9/6\lim_{u\to\pi/2^{-}}\frac{2}{\cos^{7}{u}+-8\tan^{4}{u}}       0.00      0.00      0.00         1
#                                                                                                                                                            9/6\lim_{x\to8}\frac{\sec{\left(2x\right)}}{8x}       0.00      0.00      0.00         1
#                                                                                                                                                               9/7\lim_{x\to\infty}\frac{\sin{4/x}}{x^{-2}}       0.00      0.00      0.00         1
#                                                                                              9/8\lim_{w\to3}\frac{\frac{\tan{\left(2w\right)}}{7w}\tan{\left(9w\right)}}{\frac{\sin{\left(3w\right)}}{3w}}       0.00      0.00      0.00         1
#                                                                                                                                                     9/8\lim_{x\to\pi/7^{-}}\frac{9x+-6\pi}{\sin{x}\sin{x}}       0.00      0.00      0.00         1
#                                                                                                                                                     9/9\lim_{c\to\pi/5^{-}}\frac{5c+-8\pi}{\tan{c}\sin{c}}       0.00      0.00      0.00         1
#                                                                                                                                     9/9\lim_{h\to\pi/2^{-}}\frac{7\left(8h+-5\pi\right)}{-2\sin{h}\sec{h}}       0.00      0.00      0.00         1
#                                                                                                                                                                9\lim_{v\to3}\frac{\csc{\left(v\right)}}{v}       0.00      0.00      0.00         1
#                                                                                                                                                                                       9\lim_{x\to-\infty}x       0.00      0.00      0.00         1
#                                                                                                                                                             =-6\lim_{s\to-\infty}\ln{\left|s^{2}+4\right|}       0.00      0.00      0.00         1
#                                                                                                                                                              =0\lim_{x\to-\infty}\ln{\left|x^{1}+3\right|}       0.00      0.00      0.00         1
#                                                                                                                                                                                      =1\lim_{x\to-\infty}x       0.00      0.00      0.00         1
#                                                                                                                                                =2/7\lim_{x\to\pi/3^{-}}\frac{3}{\cos^{9}{x}+-2\cos^{7}{x}}       0.00      0.00      0.00         1
#                                                                        =3/2\lim_{\theta\to\pi/9^{-}}\frac{\frac{d}{d\theta}\left(8\theta+\left(-2\pi\right)^{2}\right)}{\frac{d}{d\theta}\tan^{6}{\theta}}       0.00      0.00      0.00         1
#                                                                                             =4/5\lim_{k\to2}\frac{\frac{\sin{\left(2k\right)}}{3k}\sin{\left(4k\right)}}{\frac{\cos{\left(4k\right)}}{2k}}       0.00      0.00      0.00         1
#                                                                                                                                                    =5/2\lim_{h\to\pi/7^{-}}\frac{2h+-4\pi}{\cos{h}\tan{h}}       0.00      0.00      0.00         1
#                                                                                             =5/2\lim_{u\to3}\frac{\frac{\sin{\left(8u\right)}}{2u}\cos{\left(7u\right)}}{\frac{\sin{\left(4u\right)}}{9u}}       0.00      0.00      0.00         1
#                                                                                                                                                         =5/2\lim_{x\to8}\frac{\csc{\left(3x\right)}}{x}3/8       0.00      0.00      0.00         1
#                                                                                                                                                =8/4\lim_{r\to\pi/5^{-}}\frac{7}{\sin^{3}{r}+-5\csc^{9}{r}}       0.00      0.00      0.00         1
#                                                                                             =9/8\lim_{u\to3}\frac{\frac{\sin{\left(4u\right)}}{2u}\cos{\left(6u\right)}}{\frac{\cos{\left(8u\right)}}{2u}}       0.00      0.00      0.00         1
#                                                                                                                                                =\frac{-5\lim_{h\to2}h^{2}}{\lim_{h\to3}5h+7^{\frac{7}{2}}}       0.00      0.00      0.00         1
#                                                                                                                              =\frac{3}{2}\lim_{x\to\infty}\frac{3\sec{\frac{9}{x}}}{x^{7}}\frac{x^{2}}{-2}       0.00      0.00      0.00         1
#                                                                                     =\frac{4}{2}\lim_{z\to3}\frac{\frac{\sin{\left(9z\right)}}{7z}\tan{\left(9z\right)}}{\frac{\tan{\left(8z\right)}}{7z}}       0.00      0.00      0.00         1
#                                                                                                                                                   =\frac{4}{5}\lim_{s\to5}\frac{\sin{\left(2s\right)}}{9s}       0.00      0.00      0.00         1
#                                                                          =\frac{4}{9}\lim_{y\to\infty}\frac{\frac{d}{dy}\left(\tan{\frac{3}{y}}+-9\frac{3}{y}\sin{\frac{5}{y}}\right)}{\frac{d}{dy}y^{-7}}       0.00      0.00      0.00         1
#                                                                                                                                                             =\frac{6}{67}\lim_{h\to2}\tan{\left(4h\right)}       0.00      0.00      0.00         1
# ...
#                                                                                                                                                                                      e^{\lim_{n\to1^{+}}2}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{r\to0^{+}}\frac{\frac{d}{dr}\ln{\left(1+r\right)}}{\frac{d}{dr}\cot{r}}}       0.00      0.00      0.00         1
#                                                                                                                                                                               e^{\lim_{r\to2^{+}}\lnr^{r}}       0.00      0.00      0.00         1
#                                                                                                                                                                              e^{\lim_{s\to9^{+}}6\cdot-4s}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{s\to9^{+}}\frac{\frac{2}{s+2}}{\sin{s}}}       0.00      0.00      0.00         1
#                                                                                                                                                                e^{\lim_{t\to3^{+}}\frac{\ln{t}}{3+\ln{t}}}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{t\to5^{+}}\frac{\frac{d}{dt}\ln{\left(9+t\right)}}{\frac{d}{dt}\sin{t}}}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{t\to7^{+}}\frac{\frac{d}{dt}\ln{\left(9+t\right)}}{\frac{d}{dt}\cos{t}}}       0.00      0.00      0.00         1
#                                                                                                                                                                e^{\lim_{u\to0^{+}}\frac{\ln{u}}{2+\ln{u}}}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{u\to2^{+}}\frac{\frac{d}{du}\ln{\left(1+u\right)}}{\frac{d}{du}\sin{u}}}       0.00      0.00      0.00         1
#                                                                                                                                                                                      e^{\lim_{u\to6^{+}}1}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{u\to6^{+}}\frac{\frac{5}{u+5}}{\sin{u}}}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{u\to8^{+}}\frac{\frac{2}{u+5}}{\cot{u}}}       0.00      0.00      0.00         1
#                                                                                                                                                                                    e^{\lim_{v\to8^{+}}0-v}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{v\to8^{+}}\frac{\frac{7}{v+3}}{\cos{v}}}       0.00      0.00      0.00         1
#                                                                                                                                                                                      e^{\lim_{x\to0^{+}}2}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{x\to2^{+}}\frac{\frac{4}{x+7}}{\tan{x}}}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{x\to2^{+}}\frac{\frac{8}{x+5}}{\sin{x}}}       0.00      0.00      0.00         1
#                                                                                                                                                                               e^{\lim_{x\to3^{+}}\lnx^{x}}       0.00      0.00      0.00         1
#                                                                                                                                                                              e^{\lim_{x\to5^{+}}7\cdot-7x}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{x\to7^{+}}\frac{\frac{3}{x+2}}{\sin{x}}}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{x\to7^{+}}\frac{\frac{3}{x+7}}{\tan{x}}}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{x\to7^{+}}\frac{\frac{d}{dx}\ln{\left(9+x\right)}}{\frac{d}{dx}\sin{x}}}       0.00      0.00      0.00         1
#                                                                                                                                    e^{\lim_{x\to9^{+}}4\frac{\frac{d}{dx}\ln{x}}{\frac{d}{dx}\frac{8}{x}}}       0.00      0.00      0.00         1
#                                                                                                                                                                              e^{\lim_{x\to9^{+}}9\cdot-6x}       0.00      0.00      0.00         1
#                                                                                                                                                        e^{\lim_{x\to9^{+}}\frac{\frac{8}{x}}{\frac{7}{x}}}       0.00      0.00      0.00         1
#                                                                                                                          e^{\lim_{y\to4^{+}}\frac{\frac{d}{dy}\ln{\left(3+y\right)}}{\frac{d}{dy}\tan{y}}}       0.00      0.00      0.00         1
#                                                                                                                                                        e^{\lim_{y\to6^{+}}\frac{\frac{3}{y}}{\frac{6}{y}}}       0.00      0.00      0.00         1
#                                                                                                                                                                                      e^{\lim_{z\to1^{+}}2}       0.00      0.00      0.00         1
#                                                                                                                                                        e^{\lim_{z\to4^{+}}\frac{\frac{9}{z}}{\frac{3}{z}}}       0.00      0.00      0.00         1
#                                                                                                                                                          e^{\lim_{z\to7^{+}}\frac{\frac{5}{z+7}}{\tan{z}}}       0.00      0.00      0.00         1
#                                                                                                                                                                  g=\lim_{t\to5^{+}}\left|\ln{t}\right|^{t}       0.00      0.00      0.00         1
#                                                                                                                                                                  h=\lim_{c\to8^{+}}\left|\ln{c}\right|^{c}       0.00      0.00      0.00         1
#                                                                                                                                                                  h=\lim_{k\to4^{+}}\left|\ln{k}\right|^{k}       0.00      0.00      0.00         1
#                                                                                                                                                                  h=\lim_{v\to1^{+}}\left|\ln{v}\right|^{v}       0.00      0.00      0.00         1
#                                                                                                                                                                  h=\lim_{x\to0^{+}}\left|\ln{x}\right|^{x}       0.00      0.00      0.00         1
#                                                                                                                                                                  n=\lim_{h\to8^{+}}\left|\ln{h}\right|^{h}       0.00      0.00      0.00         1
#                                                                                                                                                                  n=\lim_{t\to1^{+}}\left|\ln{t}\right|^{t}       0.00      0.00      0.00         1
#                                                                                                                                                                  n=\lim_{t\to7^{+}}\left|\ln{t}\right|^{t}       0.00      0.00      0.00         1
#                                                                                                                                                                  n\lim_{u\to6}\frac{u^{7}+-u}{u^{6}+-5u+5}       0.00      0.00      0.00         1
#                                                                                                                                                                  p=\lim_{a\to8^{+}}\left|\ln{a}\right|^{a}       0.00      0.00      0.00         1
#                                                                                                                                                                  p=\lim_{t\to5^{+}}\left|\ln{t}\right|^{t}       0.00      0.00      0.00         1
#                                                                                                                                                                  r=\lim_{w\to2^{+}}\left|\ln{w}\right|^{w}       0.00      0.00      0.00         1
#                                                                                                                                                   s=\lim_{\theta\to1^{+}}\left|\ln{\theta}\right|^{\theta}       0.00      0.00      0.00         1
#                                                                                                                                                                  s\lim_{x\to0}\frac{x^{8}+-x}{x^{7}+-5x+1}       0.00      0.00      0.00         1
#                                                                                                                                                                  t=\lim_{k\to6^{+}}\left|\ln{k}\right|^{k}       0.00      0.00      0.00         1
#                                                                                                                                                                  t=\lim_{w\to5^{+}}\left|\ln{w}\right|^{w}       0.00      0.00      0.00         1
#                                                                                                                                                   u=\lim_{\theta\to3^{+}}\left|\ln{\theta}\right|^{\theta}       0.00      0.00      0.00         1
#                                                                                                                                                                  u\lim_{h\to1}\frac{h^{1}+-5h}{h^{2}+-h+9}       0.00      0.00      0.00         1
#                                                                                                                                                                 w\lim_{h\to6}\frac{h^{3}+-9h}{h^{8}+-3h+9}       0.00      0.00      0.00         1
#                                                                                                                                                   x=\lim_{\theta\to6^{+}}\left|\ln{\theta}\right|^{\theta}       0.00      0.00      0.00         1
#                                                                                                                                                                  x=\lim_{b\to7^{+}}\left|\ln{b}\right|^{b}       0.00      0.00      0.00         1
#                                                                                                                                                                  x=\lim_{t\to8^{+}}\left|\ln{t}\right|^{t}       0.00      0.00      0.00         1
#                                                                                                                                                                  x=\lim_{w\to1^{+}}\left|\ln{w}\right|^{w}       0.00      0.00      0.00         1
#                                                                                                                                                                  x=\lim_{w\to2^{+}}\left|\ln{w}\right|^{w}       0.00      0.00      0.00         1
#                                                                                                                                                                  x=\lim_{z\to1^{+}}\left|\ln{z}\right|^{z}       0.00      0.00      0.00         1
#                                                                                                                                                                  y=\lim_{g\to2^{+}}\left|\ln{g}\right|^{g}       0.00      0.00      0.00         1
#                                                                                                                                                                  y=\lim_{u\to7^{+}}\left|\ln{u}\right|^{u}       0.00      0.00      0.00         1
#                                                                                                                                                                  y=\lim_{x\to3^{+}}\left|\ln{x}\right|^{x}       0.00      0.00      0.00         1
#                                                                                                                                                                  y=\lim_{x\to7^{+}}\left|\ln{x}\right|^{x}       0.00      0.00      0.00         1
#                                                                                                                                                                  z=\lim_{x\to1^{+}}\left|\ln{x}\right|^{x}       0.00      0.00      0.00         1
#
#                                                                                                                                                                                                   accuracy                           0.00     10000
#                                                                                                                                                                                                  macro avg       0.00      0.00      0.00     10000
#                                                                                                                                                                                               weighted avg       0.00      0.00      0.00     10000
# c:\Users\Nitish\Desktop\Minor prj\heqn\.env39\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ---

# %% [markdown]
# **Compile the Model**

# %%
# from tensorflow.keras.optimizers import Adam
# model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the Model
#
# **Prepare Data for Training**
#
# Convert annotations to a format suitable for training (e.g., one-hot encoding for classification).

# %%
# from tensorflow.keras.utils import to_categorical

# # Assuming annotations contain class labels
# labels = [annotation['label'] for annotation in annotations]
# labels_one_hot = to_categorical(labels, num_classes=num_classes)

# %%
# train the model
# model.fit(processed_images, labels_one_hot, epochs=10, batch_size=32, validation_split=0.2)

# %%
# evaluate model
# model.evaluate(validation_images, validation_labels)
